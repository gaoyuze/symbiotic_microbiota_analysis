# %%
import qiime2
import pandas as pd
import os
from qiime2.plugins import (feature_table, alignment, phylogeny, diversity)
from tqdm import tqdm

base_dir = os.getcwd()
results_dir = os.path.join(base_dir, 'results')
merged_dir = os.path.join(results_dir, 'merged')
data_dir = os.path.join(base_dir, 'data')

# merged_alpha_dir: Directory to save alpha diversity results
merged_alpha_dir = os.path.join(merged_dir, 'alpha')

def cal_alpha_diversity(sample_metadata_df, table_clean, rooted_tree):
    '''Calculate alpha diversity metrics and return a DataFrame with results.
    Args:
        sample_metadata_df (pd.DataFrame): DataFrame containing sample metadata.
        table_clean (qiime2.Artifact): Cleaned feature table artifact.
        rooted_tree (qiime2.Artifact): Rooted phylogenetic tree artifact.
    Returns:
        pd.DataFrame: DataFrame containing alpha diversity metrics.'''
    alpha_shannon = diversity.pipelines.alpha(table = table_clean, 
                                              metric = 'shannon').alpha_diversity.view(qiime2.Metadata).to_dataframe()
    alpha_evenness = diversity.pipelines.alpha(table = table_clean, 
                                                     metric = 'pielou_e').alpha_diversity.view(qiime2.Metadata).to_dataframe()
    alpha_observed_features = diversity.pipelines.alpha(table = table_clean, 
                                                        metric = 'observed_features').alpha_diversity.view(qiime2.Metadata).to_dataframe()
    alpha_faith_pd = diversity.pipelines.alpha_phylogenetic(table = table_clean, 
                                                            phylogeny = rooted_tree, 
                                                            metric='faith_pd').alpha_diversity.view(qiime2.Metadata).to_dataframe()

    alpha_df = pd.merge(sample_metadata_df[['ProjectID','HostName','BodySite', 'BodysiteClass']],
                        alpha_shannon, 
                        left_index=True, right_index=True, how='left')
    alpha_df = pd.merge(alpha_df, 
                        alpha_evenness, left_index=True, right_index=True, how='left')
    alpha_df = pd.merge(alpha_df, 
                        alpha_observed_features, left_index=True, right_index=True, how='left')
    alpha_df = pd.merge(alpha_df, 
                        alpha_faith_pd, left_index=True, right_index=True, how='left')
    return alpha_df

# %%
# Constructs a phylogenetic tree.
merged_rep_seqs = qiime2.Artifact.load(os.path.join(merged_dir, 'merged_rep_seqs.qza'))
aligned_rep_seqs = alignment.methods.mafft(merged_rep_seqs, n_threads = 16).alignment
masked_aligned_rep_seqs = alignment.methods.mask(aligned_rep_seqs).masked_alignment
masked_aligned_rep_seqs.save(os.path.join(merged_dir, 'masked_aligned_rep_seqs'))
masked_aligned_rep_seqs = qiime2.Artifact.load(os.path.join(merged_dir, 'masked_aligned_rep_seqs.qza'))
unrooted_tree = phylogeny.methods.fasttree(masked_aligned_rep_seqs, n_threads = 16).tree
unrooted_tree.save(os.path.join(merged_dir, 'unrooted_tree'))
rooted_tree = phylogeny.methods.midpoint_root(unrooted_tree).rooted_tree
rooted_tree.save(os.path.join(merged_dir, 'rooted_tree'))
# rooted_tree = qiime2.Artifact.load(os.path.join(merged_dir, 'rooted_tree.qza'))
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 16 /tmp/qiime2/gaoyuze/data/35829b82-f43b-4bb9-9067-8a82217f6a33/data/dna-sequences.fasta
# inputfile = orig
# 1131 x 390 - 145 d
# nthread = 16
# nthreadpair = 16
# nthreadtb = 16
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#  1101 / 1131 (thread   12)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#  1120 / 1131
# done.
#
# Progressive alignment 1/2...
# STEP   103 / 1130 (thread   11)
# Reallocating..done. *alloclen = 1781
# STEP  1101 / 1130 (thread    7)
# done.
#
# Making a distance matrix from msa..
#  1100 / 1131 (thread    3)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#  1120 / 1131
# done.
#
# Progressive alignment 2/2...
# STEP   382 / 1130 (thread   13)
# Reallocating..done. *alloclen = 1782
# STEP  1101 / 1130 (thread    7) h
# done.
#
# disttbfast (nuc) Version 7.520
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 16 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTreeMP -quote -nt /tmp/qiime2/gaoyuze/data/f52b7e00-570b-4fe2-89f9-9b3de90c9d0a/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.11 Double precision (No SSE3), OpenMP (16 threads)
# Alignment: /tmp/qiime2/gaoyuze/data/f52b7e00-570b-4fe2-89f9-9b3de90c9d0a/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.13 seconds: Joined    200 of   1113
#       0.23 seconds: Joined    400 of   1113
#       0.34 seconds: Joined    600 of   1113
#       0.44 seconds: Joined    800 of   1113
#       0.54 seconds: Joined   1000 of   1113
# Initial topology in 0.62 seconds
# Refining topology: 40 rounds ME-NNIs, 2 rounds ME-SPRs, 20 rounds ML-NNIs
#       0.65 seconds: ME NNI round 2 of 40, 101 of 1114 splits, 12 changes (max delta 0.015)
#       0.80 seconds: SPR round   1 of   2, 101 of 2230 nodes
#       0.93 seconds: SPR round   1 of   2, 401 of 2230 nodes
#       1.03 seconds: SPR round   1 of   2, 601 of 2230 nodes
#       1.14 seconds: SPR round   1 of   2, 801 of 2230 nodes
#       1.27 seconds: SPR round   1 of   2, 1101 of 2230 nodes
#       1.41 seconds: SPR round   1 of   2, 1401 of 2230 nodes
#       1.54 seconds: SPR round   1 of   2, 1701 of 2230 nodes
#       1.66 seconds: SPR round   1 of   2, 1901 of 2230 nodes
#       1.76 seconds: SPR round   1 of   2, 2101 of 2230 nodes
#       1.86 seconds: ME NNI round 14 of 40, 901 of 1114 splits, 16 changes (max delta 0.016)
#       2.01 seconds: SPR round   2 of   2, 201 of 2230 nodes
#       2.16 seconds: SPR round   2 of   2, 501 of 2230 nodes
#       2.31 seconds: SPR round   2 of   2, 801 of 2230 nodes
#       2.44 seconds: SPR round   2 of   2, 1101 of 2230 nodes
#       2.58 seconds: SPR round   2 of   2, 1401 of 2230 nodes
#       2.70 seconds: SPR round   2 of   2, 1601 of 2230 nodes
#       2.83 seconds: SPR round   2 of   2, 1901 of 2230 nodes
#       2.97 seconds: SPR round   2 of   2, 2201 of 2230 nodes
# Total branch-length 39.319 after 3.08 sec
#       3.08 seconds: ML Lengths 1 of 1114 splits
#       3.19 seconds: ML Lengths 401 of 1114 splits
#       3.29 seconds: ML Lengths 801 of 1114 splits
#       3.42 seconds: ML NNI round 1 of 20, 101 of 1114 splits, 15 changes (max delta 2.221)
#       3.56 seconds: ML NNI round 1 of 20, 401 of 1114 splits, 76 changes (max delta 7.138)
#       3.71 seconds: ML NNI round 1 of 20, 701 of 1114 splits, 137 changes (max delta 9.441)
#       3.81 seconds: ML NNI round 1 of 20, 901 of 1114 splits, 184 changes (max delta 10.111)
# ML-NNI round 1: LogLk = -45864.503 NNIs 221 max delta 10.11 Time 3.93
#       3.94 seconds: Site likelihoods with rate category 1 of 20
#       4.05 seconds: Site likelihoods with rate category 10 of 20
#       4.15 seconds: Site likelihoods with rate category 19 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.947 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#       4.28 seconds: ML NNI round 2 of 20, 201 of 1114 splits, 19 changes (max delta 3.357)
#       4.39 seconds: ML NNI round 2 of 20, 401 of 1114 splits, 45 changes (max delta 6.797)
#       4.50 seconds: ML NNI round 2 of 20, 601 of 1114 splits, 64 changes (max delta 6.797)
#       4.61 seconds: ML NNI round 2 of 20, 801 of 1114 splits, 87 changes (max delta 6.797)
#       4.72 seconds: ML NNI round 2 of 20, 1001 of 1114 splits, 115 changes (max delta 7.679)
# ML-NNI round 2: LogLk = -38298.614 NNIs 125 max delta 7.68 Time 4.79
#       4.84 seconds: ML NNI round 3 of 20, 101 of 1114 splits, 10 changes (max delta 4.794)
#       4.95 seconds: ML NNI round 3 of 20, 301 of 1114 splits, 36 changes (max delta 6.288)
#       5.05 seconds: ML NNI round 3 of 20, 501 of 1114 splits, 45 changes (max delta 6.288)
#       5.16 seconds: ML NNI round 3 of 20, 701 of 1114 splits, 60 changes (max delta 6.288)
# ML-NNI round 3: LogLk = -38222.253 NNIs 65 max delta 6.29 Time 5.22
#       5.27 seconds: ML NNI round 4 of 20, 101 of 1114 splits, 8 changes (max delta 0.961)
#       5.38 seconds: ML NNI round 4 of 20, 301 of 1114 splits, 24 changes (max delta 7.105)
#       5.49 seconds: ML NNI round 4 of 20, 501 of 1114 splits, 37 changes (max delta 7.105)
# ML-NNI round 4: LogLk = -38195.653 NNIs 37 max delta 7.10 Time 5.50
#       5.61 seconds: ML NNI round 5 of 20, 201 of 1114 splits, 8 changes (max delta 0.971)
# ML-NNI round 5: LogLk = -38185.816 NNIs 12 max delta 2.84 Time 5.69
#       5.74 seconds: ML NNI round 6 of 20, 101 of 1114 splits, 6 changes (max delta 1.748)
# ML-NNI round 6: LogLk = -38179.999 NNIs 6 max delta 1.75 Time 5.80
# ML-NNI round 7: LogLk = -38177.757 NNIs 3 max delta 1.50 Time 5.84
# ML-NNI round 8: LogLk = -38177.669 NNIs 3 max delta 0.03 Time 5.89
# Turning off heuristics for final round of ML NNIs (converged)
#       5.88 seconds: ML NNI round 9 of 20, 1 of 1114 splits
#       5.99 seconds: ML NNI round 9 of 20, 201 of 1114 splits, 5 changes (max delta 0.243)
#       6.09 seconds: ML NNI round 9 of 20, 401 of 1114 splits, 10 changes (max delta 0.807)
#       6.21 seconds: ML NNI round 9 of 20, 601 of 1114 splits, 11 changes (max delta 0.807)
#       6.32 seconds: ML NNI round 9 of 20, 801 of 1114 splits, 13 changes (max delta 0.807)
#       6.42 seconds: ML NNI round 9 of 20, 1001 of 1114 splits, 15 changes (max delta 0.807)
# ML-NNI round 9: LogLk = -38170.350 NNIs 16 max delta 0.81 Time 6.49 (final)
#       6.53 seconds: ML Lengths 201 of 1114 splits
#       6.63 seconds: ML Lengths 701 of 1114 splits
# Optimize all lengths: LogLk = -38169.545 Time 6.73
#       6.82 seconds: ML split tests for    100 of   1113 internal splits
#       6.93 seconds: ML split tests for    200 of   1113 internal splits
#       7.03 seconds: ML split tests for    300 of   1113 internal splits
#       7.23 seconds: ML split tests for    500 of   1113 internal splits
#       7.33 seconds: ML split tests for    600 of   1113 internal splits
#       7.44 seconds: ML split tests for    700 of   1113 internal splits
#       7.64 seconds: ML split tests for    900 of   1113 internal splits
#       7.74 seconds: ML split tests for   1000 of   1113 internal splits
# Total time: 7.86 seconds Unique: 1116/1131 Bad splits: 1/1113 Worst delta-LogLk 4.789
# '/home/gaoyuze/symbiotic_microbiota_analysis/results/merged/rooted_tree.qza'

# %%
sample_metadata = qiime2.Metadata.load(os.path.join(data_dir, 'sample_metadata.txt'))
merged_table_clean = qiime2.Artifact.load(os.path.join(merged_dir, 'merged_table_clean.qza'))

alpha_df = pd.DataFrame(
    columns=['SampleID','ProjectID', 'HostName', 'BodySite','shannon_entropy','pielou_evenness', 'observed_features', 'faith_pd']
)
alpha_df = cal_alpha_diversity(sample_metadata.to_dataframe(), merged_table_clean, rooted_tree)
alpha_df.reset_index(inplace=True)
alpha_df.to_csv(os.path.join(merged_alpha_dir, 'alpha_diversity.csv'), index=False)

print('STEP 5  Done!')
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /tmp/qiime2/gaoyuze/data/0036ba6b-337e-4a6e-b5f4-0309d2b4dc06/data/feature-table.biom -t /tmp/qiime2/gaoyuze/data/73382eed-be36-45ce-b307-2c12fafee5a4/data/tree.nwk -o /tmp/q2-AlphaDiversityFormat-a2h0g6u7
#
# STEP 5  Done!

# %%
alpha_df
# Out:
#        SampleID    ProjectID             HostName     BodySite  \
# 0   SRR23216662  PRJNA924021   Terrapene carolina       Cloaca
# 1   SRR23216663  PRJNA924021   Terrapene carolina       Cloaca
# 2   SRR23216664  PRJNA924021   Terrapene carolina       Cloaca
# 3   SRR23216665  PRJNA924021   Terrapene carolina       Cloaca
# 4   SRR23216666  PRJNA924021   Terrapene carolina       Cloaca
# 5   SRR23216667  PRJNA924021   Terrapene carolina       Cloaca
# 6    ERR1474235   PRJEB14602  Varanus komodoensis        feces
# 7    ERR1474236   PRJEB14602  Varanus komodoensis  oral cavity
# 8    ERR1474237   PRJEB14602  Varanus komodoensis         skin
# 9    ERR1474238   PRJEB14602  Varanus komodoensis        feces
# 10   ERR1474239   PRJEB14602  Varanus komodoensis  oral cavity
# 11   ERR1474240   PRJEB14602  Varanus komodoensis        feces
# 12   ERR1474244   PRJEB14602  Varanus komodoensis         skin
# 13   ERR1474246   PRJEB14602  Varanus komodoensis  oral cavity
# 14   ERR1474247   PRJEB14602  Varanus komodoensis         skin
# 15   ERR1474248   PRJEB14602  Varanus komodoensis        feces
# 16   ERR1474249   PRJEB14602  Varanus komodoensis  oral cavity
# 17   ERR1474250   PRJEB14602  Varanus komodoensis         skin
# 18   ERR1474251   PRJEB14602  Varanus komodoensis        feces
#
#           BodysiteClass  shannon_entropy  pielou_evenness  observed_features  \
# 0        CloacaReptilia         4.461310         0.618814              148.0
# 1        CloacaReptilia         4.299742         0.608504              134.0
# 2        CloacaReptilia         4.197208         0.610915              117.0
# 3        CloacaReptilia         4.419209         0.618093              142.0
# 4        CloacaReptilia         4.248253         0.588468              149.0
# 5        CloacaReptilia         4.695012         0.650354              149.0
# 6         FecesReptilia         5.288433         0.717920              165.0
# 7   Oral_cavityReptilia         6.785875         0.779326              418.0
# 8          SkinReptilia         5.491313         0.780745              131.0
# 9         FecesReptilia         4.663354         0.746384               76.0
# 10  Oral_cavityReptilia         5.960530         0.774750              207.0
# 11        FecesReptilia         3.506722         0.537547               92.0
# 12         SkinReptilia         4.734163         0.638941              170.0
# 13  Oral_cavityReptilia         4.844038         0.585303              310.0
# 14         SkinReptilia         4.182698         0.520662              262.0
# 15        FecesReptilia         4.777043         0.648498              165.0
# 16  Oral_cavityReptilia         4.741792         0.728633               91.0
# 17         SkinReptilia         6.209409         0.827938              181.0
# 18        FecesReptilia         4.595366         0.625328              163.0
#
#      faith_pd
# 0   10.186701
# 1    9.457109
# 2    8.937190
# 3    9.666447
# 4   10.929740
# 5   10.929740
# 6   11.020333
# 7   24.741341
# 8   10.852530
# 9    5.798360
# 10  13.912648
# 11   7.823783
# 12  11.930946
# 13  19.986006
# 14  17.202763
# 15  10.162000
# 16   7.808734
# 17  12.044051
# 18  11.084091
